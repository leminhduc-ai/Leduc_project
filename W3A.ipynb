# %%
#W3A2
a,b=map (int , input() . split())
a = a ^ b
b = a ^ b
a = a ^ b
print(a , b)
# Out:
#  5 3
# 3 5

# %%
#W3A3
n = int (input())
while n > 0:
    if n & (n-1) == 0:
        print("True")
        break
    else:
        print("False")
        break
# Out:
#  100
# False

# %%
#W3A4, W3A5
import math
m,n = map(int, input().split())
x = m / n
print(math.ceil(x))
print(math.floor(x))
# Out:
#  11 4
# 3
# 2

# %%
#W3A6
while True:
    try:
        x = int(input())
        if x < 0.1:
            print("Nhap so nguyen duong")
        else: 
            break
    except ValueError:
        print("Nhap lỗi")
if x % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
#  9
# Odd

# %%
#W3A7
while True:
    try:
        a,b = map(int, input().split())
        if a and b < 0.1:
            print("Yes")
            break
        else: 
            print("No")
            break
    except ValueError:
        print("Nhap lỗi")
# Out:
#  -8 9
# No

# %%
#W3A8
x = input()
y = input()
a = str(x)
b = str(y)
if len(str(a)) > len(str(b)):
    print("Yes")
else:
    print("No")
# Out:
#  bfsndv
#  f
# Yes

# %%
#W3A9
while True:
    try:
        a,b,c = map(int, input().split())
        if a < 0.1 and b < 0.1 and c < 0.1:
            print("Nhap so nguyen duong")
        else:
            break
    except ValueError:
        print("Nhap lỗi")
if a+b > c and b+c > a and a+c > b:
    print("Yes")
else:
    print("No")
# Out:
#   6 78
# Nhap lỗi
#  6 7 8
# Yes

# %%
#W3A10
a,b,c,d = map(int, input().split())
print(max(a,b,c,d))
# Out:
#  8 808 88 797
# 808

# %%
#W3A11
a,b,c = map(int, input().split())
if a+b <= c or b+c <= a or a+c <= b:
    print("Không phải tam giác")
elif a == b == c:
    print("Tam giác đều")
elif a == b or b == c or c == a:
    print("Tam giác cân")
else:
    print("Tam giác thường")
# Out:
#  10 10 7
# Tam giác cân

# %%
#A12
n = int(input())
if n % 4 == 0 and n % 100 != 0:
    print("Yes")
elif n % 400 == 0:
    print("Yes")
else:
    print("No")
# Out:
#  2000
# Yes

# %%
#A14
a,b = map(int, input().split())
x = -b/a
if a == 0 and b == 0:
    print("Vô số nghiệm")
elif a == 0 and b != 0:
    print("Vô nghiệm")
else:
    print(f'{x:.2f}')
# Out:
#  7 5
# -0.71

# %%
#A15
x = int(input())
if 0 <= x <= 10:
    if x >= 8:
        print("Giỏi")
    elif x >= 6.5:
        print("Khá")
    elif x >= 5.0:
        print("Trung bình")
    elif x < 5.0: 
        print("Yếu")
else: 
    print("Vui lòng nhập đúng điểm")
# Out:
#  10
# Giỏi

# %%
#A16
x = float(input())
tron_len = x // 1 + 1
tron_xuong = x // 1
print(tron_len)
print(tron_xuong)
# Out:
#  6.78
# 7.0
# 6.0

# %%
#A17
a,b,c,d = map(float, input().split())
x = b / a
if b*x == c and c*x == d:
    print("Có là cấp số nhân")
else:
    print("Không")
# Out:
#  1 0.5 0.25 0.125
# Có là cấp số nhân
